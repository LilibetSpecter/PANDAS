# %% [markdown]
# ## Pandas Veri Analizi - U.S Major League Soccer Salaries Veri Analizi

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### VeriSetini Okuyun

# %%
df=pd.read_csv("mls-salaries-2017.csv")
df
# Out:
#     club last_name    first_name position  base_salary  \
# 0    ATL   Almiron        Miguel        M    1912500.0
# 1    ATL   Ambrose         Mikey        D      65625.0
# 2    ATL      Asad         Yamil        M     150000.0
# 3    ATL     Bloom          Mark        D      99225.0
# 4    ATL  Carleton        Andrew        F      65000.0
# ..   ...       ...           ...      ...          ...
# 611  VAN  Tornaghi         Paolo       GK      80000.0
# 612  VAN    Waston       Kendall        D     350000.0
# 613  VAN  Williams       Sheanon        D     175000.0
# 614  NaN   Babouli            Mo        F      54075.0
# 615  NaN    Ramajo  David Mateos        D     420000.0
#
#      guaranteed_compensation
# 0                 2297000.00
# 1                   65625.00
# 2                  150000.00
# 3                  106573.89
# 4                   77400.00
# ..                       ...
# 611                 80000.00
# 612                368125.00
# 613                184000.00
# ...

# %%
# Out:
#   club last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL   Almiron     Miguel        M    1912500.0               2297000.00
# 1  ATL   Ambrose      Mikey        D      65625.0                 65625.00
# 2  ATL      Asad      Yamil        M     150000.0                150000.00
# 3  ATL     Bloom       Mark        D      99225.0                106573.89
# 4  ATL  Carleton     Andrew        F      65000.0                 77400.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club                     614 non-null    object
#  1   last_name                616 non-null    object
#  2   first_name               612 non-null    object
#  3   position                 616 non-null    object
#  4   base_salary              616 non-null    float64
#  5   guaranteed_compensation  616 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 29.0+ KB

# %% [markdown]
# #### Eksik veri kontrolü yapın

# %%
# eksik verilerin doldurulması hakkında yorum yapın

# %%
df.isnull().sum()
#eksik degerleri numeric ise mesela  mean ile doldurabiliyoruz
# Out:
# club                       2
# last_name                  0
# first_name                 4
# position                   0
# base_salary                0
# guaranteed_compensation    0
# dtype: int64

# %% [markdown]
# #### İlk 10 Veriyi Okuyun / Rastgele 5 veriyi getirin

# %%
df.head(10)
# Out:
#   club       last_name first_name position  base_salary  \
# 0  ATL         Almiron     Miguel        M    1912500.0
# 1  ATL         Ambrose      Mikey        D      65625.0
# 2  ATL            Asad      Yamil        M     150000.0
# 3  ATL           Bloom       Mark        D      99225.0
# 4  ATL        Carleton     Andrew        F      65000.0
# 5  ATL         Carmona     Carlos        M     675000.0
# 6  ATL           Garza       Greg        D     150000.0
# 7  ATL  Gonzalez Pirez    Leandro        D     250008.0
# 8  ATL          Goslin      Chris        M      70000.0
# 9  ATL         Gressel     Julian        M      75000.0
#
#    guaranteed_compensation
# 0               2297000.00
# 1                 65625.00
# 2                150000.00
# 3                106573.89
# 4                 77400.00
# 5                725000.00
# 6                150000.00
# 7                285008.00
# 8                 74000.00
# 9                 93750.00

# %%
df.sample(5)
#defaultu 1, 5 yazarsam 5 getirir.
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 98   COL     Gashi   Shkelzen        F   1575000.00               1668750.00
# 296  MTL  Kronberg       Eric       GK     99999.96                104999.96
# 485  RSL    Lennon     Brooks        F     53004.00                 53004.00
# 79   CLB    Obinwa     Abuchi        M     65004.00                 65004.00
# 212   KC     Opara        Ike        D    150000.00                150000.00

# %% [markdown]
# #### Satır ve Sütun sayısını yazdırın / Sütun isimlerini yazdırın

# %%
df.shape
#satir ve sutun bilgisini getirdi.
# Out:
# (616, 6)

# %%
#sadece satir sayisina erismek istersem:
len(df.index)
# Out:
# 616

# %%
#columns isimlerini getirsin istersem:
df.columns
# Out:
# Index(['club', 'last_name', 'first_name', 'position', 'base_salary',
#        'guaranteed_compensation'],
#       dtype='object')

# %%
df["club"].value_counts()
#kategorik verilerein ne kadar degere sahip oldugunu veriyor
# Out:
# VAN      32
# PHI      31
# ATL      31
# CLB      30
# ORL      30
# DAL      29
# SJ       29
# NYCFC    28
# HOU      28
# NYRB     28
# TOR      27
# RSL      27
# POR      27
# MTL      27
# CHI      27
# MNUFC    27
# LA       27
# DC       27
# KC       26
# COL      26
# SEA      25
# NE       23
# LAFC      2
# Name: club, dtype: int64

# %%
for i in df.columns:
    print(i)
    print(df[i].value_counts())

# %% [markdown]
# #### Tüm Maaşların Ortalaması Bulun.

# %%
df.head()
# Out:
#   club last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL   Almiron     Miguel        M    1912500.0               2297000.00
# 1  ATL   Ambrose      Mikey        D      65625.0                 65625.00
# 2  ATL      Asad      Yamil        M     150000.0                150000.00
# 3  ATL     Bloom       Mark        D      99225.0                106573.89
# 4  ATL  Carleton     Andrew        F      65000.0                 77400.00

# %%
df["base_salary"].mean()
#sadece base_salary sutunundakilerin ortalamasini verir.
# Out:
# 296977.73686688306

# %% [markdown]
# #### En yüksek maaşı bulun

# %%
df["base_salary"].max()
# Out:
# 6660000.0

# %% [markdown]
# #### Ortalamanın üstünde maaş alanları bulun

# %%
df[df["last_name"]=="Almiron"]
#ismi sadece Almiron olanlari getir demis oldum boyle
df[df["base_salary"]>df["base_salary"].mean()]
#en distaki df ile cagirinca bool donen o kosulu okutabiliyoruz.
# Out:
#     club last_name    first_name position  base_salary  \
# 0    ATL   Almiron        Miguel        M   1912500.00
# 5    ATL   Carmona        Carlos        M    675000.00
# 11   ATL     Jones       Kenwyne        F    390000.00
# 16   ATL  Martinez         Josef        F    924000.00
# 17   ATL    McCann         Chris        M    540000.00
# ..   ...       ...           ...      ...          ...
# 603  VAN     Reyna         Yordy      M-F    440000.04
# 607  VAN      Shea          Brek      M-D    625000.00
# 609  VAN   Techera      Cristian        M    352000.00
# 612  VAN    Waston       Kendall        D    350000.00
# 615  NaN    Ramajo  David Mateos        D    420000.00
#
#      guaranteed_compensation
# 0                 2297000.00
# 5                  725000.00
# 11                 413333.33
# 16                1041310.00
# 17                 568000.00
# ..                       ...
# 603                533700.04
# 607                670000.00
# 609                377000.00
# ...

# %%
#mesela birden fazla kosul girecegiz diyelim, parantezle cogaltiriz
df[(df["base_salary"]>df["base_salary"].mean()) &(df["club"]=="ATL")].reset_index()
#ATL kulubundeki ortalamadan fazla maas alanlari getirdi
#reset_index diyerek de indexleri 0'dan bastan siralatiriz
# Out:
#    club  last_name first_name position  base_salary  guaranteed_compensation
# 0   ATL    Almiron     Miguel        M    1912500.0               2297000.00
# 5   ATL    Carmona     Carlos        M     675000.0                725000.00
# 11  ATL      Jones    Kenwyne        F     390000.0                413333.33
# 16  ATL   Martinez      Josef        F     924000.0               1041310.00
# 17  ATL     McCann      Chris        M     540000.0                568000.00
# 20  ATL  Parkhurst    Michael        D     325008.0                325008.00
# 27  ATL   Villalba     Hector        F     663000.0                770750.00

# %% [markdown]
# #### En yüksek tazminata sahip futbolcunun soyadını bulun

# %%
df["guaranteed_compensation"].max()
# Out:
# 'Kaka'

# %%
df[df["guaranteed_compensation"]==df["guaranteed_compensation"].max()]
#max degerini bulup, bu degere esit olani getir demis oluyoruz
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 401  ORL      Kaka        NaN        M    6660000.0                7167500.0

# %%
df[df["guaranteed_compensation"]==df["guaranteed_compensation"].max()]["last_name"].iloc[0]
#sadece soyadini getir diyoruz
#iloc ile de bu sefer sadece en bastaki gibi 'Kaka' sonucunu getiriyor
# Out:
# 401    Kaka
# Name: last_name, dtype: object

# %%
df[df["guaranteed_compensation"]==df["guaranteed_compensation"].max()][["last_name", "first_name"]].iloc[0, 1]
# Out:
# nan

# %% [markdown]
# #### "Gonzalez Pirez" isimli futbolcunun oynadığı mevkiyi bulun.

# %%
df[df["last_name"]=="Gonzalez Pirez"]["position"].iloc[0]
#soyadi Gonzalez Pirez olan oyuncunun pozisyonunu getirttik
# Out:
# 'D'

# %% [markdown]
# #### Mevkilere göre futbolcuları gruplayarak mevkilerde ortalama maaşları bulun

# %%
df.groupby("position")[["base_salary"]].mean()

# %%
# Out:
#             base_salary
# position
# D         166574.093784
# D-M       134930.000000
# F         489588.598349
# F-M       335834.000000
# F/M       125000.000000
# GK        146472.515538
# M         376106.218632
# M-D       219032.250000
# M-F       212975.604211
# M/F       550000.000000

# %% [markdown]
# #### Verisetinde kaç farklı mevki olduğunu yazdırın ve sayısını gösterin.

# %%
df["position"].value_counts()
#mevkilerin unique degerlerini de gormus oluyorum
# Out:
# M      212
# D      185
# F      109
# GK      65
# M-F     19
# D-M     14
# F-M      6
# M-D      4
# M/F      1
# F/M      1
# Name: position, dtype: int64

# %%
df["position"].unique()
#bunun
# Out:
# array(['M', 'D', 'F', 'GK', 'M-F', 'F-M', 'D-M', 'M-D', 'M/F', 'F/M'],
#       dtype=object)

# %%
len(df["position"].unique())
# Out:
# 10

# %%
df["position"].nunique()
# Out:
# 10

# %% [markdown]
# #### Her mevkide kaç oyuncunun olduğunu hesaplayın

# %%
df["position"].value_counts()
# Out:
# M      212
# D      185
# F      109
# GK      65
# M-F     19
# D-M     14
# F-M      6
# M-D      4
# M/F      1
# F/M      1
# Name: position, dtype: int64

# %% [markdown]
# #### Her takımda kaç kişinin oynadığını hesaplayın.

# %%
df["club"].value_counts()
# Out:
# VAN      32
# PHI      31
# ATL      31
# CLB      30
# ORL      30
# DAL      29
# SJ       29
# NYCFC    28
# HOU      28
# NYRB     28
# TOR      27
# RSL      27
# POR      27
# MTL      27
# CHI      27
# MNUFC    27
# LA       27
# DC       27
# KC       26
# COL      26
# SEA      25
# NE       23
# LAFC      2
# Name: club, dtype: int64

# %% [markdown]
# #### Soyadlarının içinde "son" geçen futbolcuları bulun

# %%
#bunu da contains ile yapiyorum.str.contains methodu ile
df[df["last_name"].str.contains("son")].reset_index()
# Out:
#     index   club      last_name first_name position  base_salary  \
# 0      21    ATL       Peterson      Jacob        F    165300.00
# 1      23    ATL       Robinson      Miles        D    125000.04
# 2      45    CHI        Johnson     Daniel        M     65004.00
# 3      48    CHI        Lampson       Matt       GK     76000.00
# 4      85    CLB        Swanson        Ben        M     85000.00
# 5     163     DC       Robinson      Jalen        D     69996.00
# 6     233     LA       Jamieson   Bradford        F     66150.00
# 7     265  MNUFC          Ibson        NaN        M    200004.00
# 8     276  MNUFC       Thiesson     Jerome        D    171000.00
# 9     295    MTL  Jackson-Hamel    Anthony        F     66150.00
# 10    327     NE         Watson  Je-Vaughn      D-M    150000.00
# 11    338  NYCFC       Harrison       Jack        M    130000.00
# 12    341  NYCFC        Johnson       Sean       GK    220008.00
# ...

# %%
# Out:
#       club      last_name first_name position  base_salary  \
# 21     ATL       Peterson      Jacob        F    165300.00
# 23     ATL       Robinson      Miles        D    125000.04
# 45     CHI        Johnson     Daniel        M     65004.00
# 48     CHI        Lampson       Matt       GK     76000.00
# 85     CLB        Swanson        Ben        M     85000.00
# 163     DC       Robinson      Jalen        D     69996.00
# 233     LA       Jamieson   Bradford        F     66150.00
# 265  MNUFC          Ibson        NaN        M    200004.00
# 276  MNUFC       Thiesson     Jerome        D    171000.00
# 295    MTL  Jackson-Hamel    Anthony        F     66150.00
# 327     NE         Watson  Je-Vaughn      D-M    150000.00
# 338  NYCFC       Harrison       Jack        M    130000.00
# 341  NYCFC        Johnson       Sean       GK    220008.00
# 400    ORL        Johnson       Will        M    414000.00
# 442    PHI        Simpson        Jay        F    465000.00
# ...

# %% [markdown]
# #### Takım ve mevki bilgisinin yer aldığı yeni bir sütun oluşturun

# %%
df["new_info"]=df["club"]+"-"+df["position"]
#basitce + ile birlestirerek yeni bir sutun yaptik

# %%
df

# %%
soccer.head()
# Out:
#   club last_name first_name position  base_salary  guaranteed_compensation  \
# 0  ATL   Almiron     Miguel        M    1912500.0               2297000.00
# 1  ATL   Ambrose      Mikey        D      65625.0                 65625.00
# 2  ATL      Asad      Yamil        M     150000.0                150000.00
# 3  ATL     Bloom       Mark        D      99225.0                106573.89
# 4  ATL  Carleton     Andrew        F      65000.0                 77400.00
#
#   new_info
# 0    ATL-M
# 1    ATL-D
# 2    ATL-M
# 3    ATL-D
# 4    ATL-F

# %% [markdown]
# #### En çok oyuncuya sahip takımın oyucularına yazdır

# %%
df.groupby("club").size().sort_values(ascending=False)
#value_counts ile ayni sonucu verdi size da. 
#ama sort_values yaparak yukardan asagi siralatabiliriz.
# Out:
# club
# VAN      32
# PHI      31
# ATL      31
# CLB      30
# ORL      30
# DAL      29
# SJ       29
# NYCFC    28
# HOU      28
# NYRB     28
# TOR      27
# RSL      27
# POR      27
# MTL      27
# CHI      27
# MNUFC    27
# LA       27
# DC       27
# KC       26
# COL      26
# SEA      25
# NE       23
# LAFC      2
# dtype: int64

# %%
df.groupby("club").size().nlargest(5)
# Out:
# club
# VAN    32
# ATL    31
# PHI    31
# CLB    30
# ORL    30
# dtype: int64

# %%
df["club"].value_counts().index[0]

# %%
df["club"].mode().iloc[0]
#mode bana en cok terkara edeni getiriyorudu
#iloc 0 dersem de bana direkt VAN'i getirecek
# Out:
# 'VAN'

# %%
df["club"].value_counts().idxmax()
#en fazla oyuncuya sahip oyunculari cesitli yontemlerle getirttik
# Out:
# 'VAN'

# %%
df[df["club"]=df["club"].mode().iloc[0]]
#boylece de oyuncular da getirdik
# Out:
#     club  last_name first_name position  base_salary  guaranteed_compensation  \
# 582  VAN   Adekugbe     Samuel        D     80000.00                 85000.00
# 583  VAN    Bolanos  Christian        M    250000.00                253500.00
# 584  VAN     Bustos      Marco        M     65625.00                 70475.00
# 585  VAN     Davies   Alphonso        M     65000.00                 65000.00
# 586  VAN    de Jong     Marcel      D-M    140000.00                140000.00
# 587  VAN       Dean  Christian        D    121000.00                202000.00
# 588  VAN      Edgar      David        D    175000.00                183833.33
# 589  VAN     Flores      Deybi        M     66000.00                 71885.00
# 590  VAN     Froese      Kianz        M     69300.00                 73800.00
# 591  VAN      Greig       Kyle        F     65004.00                 66849.00
# 592  VAN     Harvey     Jordan        D    180000.00                180000.00
# ...

# %% [markdown]
# #### En çok oyuncuya sahip takımı getir ancak içinden maaşı ortalamanın üstünde olanları yazdır

# %%
df[ (df["club"] == df["club"].mode().iloc[0] ) &  (df["base_salary"] > df["base_salary"].mean()) ]
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 595  VAN      Laba     Matias        M    725000.00                885500.00
# 599  VAN   Montero      Fredy        F   1400000.04               1800000.04
# 601  VAN    Ousted      David       GK    360000.00                378933.33
# 603  VAN     Reyna      Yordy      M-F    440000.04                533700.04
# 607  VAN      Shea       Brek      M-D    625000.00                670000.00
# 609  VAN   Techera   Cristian        M    352000.00                377000.00
# 612  VAN    Waston    Kendall        D    350000.00                368125.00

# %%
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation  \
# 595  VAN      Laba     Matias        M    725000.00                885500.00
# 599  VAN   Montero      Fredy        F   1400000.04               1800000.04
# 601  VAN    Ousted      David       GK    360000.00                378933.33
# 603  VAN     Reyna      Yordy      M-F    440000.04                533700.04
# 607  VAN      Shea       Brek      M-D    625000.00                670000.00
# 609  VAN   Techera   Cristian        M    352000.00                377000.00
# 612  VAN    Waston    Kendall        D    350000.00                368125.00
#
#     new_info
# 595    VAN-M
# 599    VAN-F
# 601   VAN-GK
# 603  VAN-M-F
# 607  VAN-M-D
# 609    VAN-M
# 612    VAN-D

# %% [markdown]
# #### Mevkisi sadece M-D, D-M ve F-M' den birisi olan oyuncuları getir

# %%
#bunu contains ile de yapabiliriz
#veya baglaci ile baglayarak
df[df["position"].str.contains("M-D|D-M|F-M")]

# %%
df[df["position"].isin(["M-D", "D-M", "F-M"])]
# Out:
#       club     last_name first_name position  base_salary  \
# 31     CHI         Accam      David      F-M     750000.0
# 50     CHI         Meira       Joao      D-M     150000.0
# 101    COL      Hairston     Marlon      D-M     110004.0
# 112    COL         Watts      Jared      D-M      75000.0
# 115    DAL      Akindele      Tesho      F-M      95000.0
# 121    DAL         Craft        Coy      F-M      85000.0
# 132    DAL  Hollingshead       Ryan      M-D     132500.0
# 148     DC        Durkin      Chris      D-M      70000.0
# 156     DC       Le Toux  Sebastien      F-M     125004.0
# 159     DC        Nyarko    Patrick      F-M     235000.0
# 214     KC        Pasher      Tyler      D-M      53000.0
# 325     NE       Tierney      Chris      D-M     140000.0
# 327     NE        Watson  Je-Vaughn      D-M     150000.0
# 331  NYCFC         Awuah      Kwame      D-M      53004.0
# 388    ORL        Barnes      Giles      F-M     725000.0
# ...

# %% [markdown]
# #### Mevkisi M olmayan oyuncuları getir

# %%
df[df["position"]!= "M"]
#bu bir cozum
# Out:
#     club       last_name    first_name position  base_salary  \
# 1    ATL         Ambrose         Mikey        D      65625.0
# 3    ATL           Bloom          Mark        D      99225.0
# 4    ATL        Carleton        Andrew        F      65000.0
# 6    ATL           Garza          Greg        D     150000.0
# 7    ATL  Gonzalez Pirez       Leandro        D     250008.0
# ..   ...             ...           ...      ...          ...
# 611  VAN        Tornaghi         Paolo       GK      80000.0
# 612  VAN          Waston       Kendall        D     350000.0
# 613  VAN        Williams       Sheanon        D     175000.0
# 614  NaN         Babouli            Mo        F      54075.0
# 615  NaN          Ramajo  David Mateos        D     420000.0
#
#      guaranteed_compensation new_info
# 1                   65625.00    ATL-D
# 3                  106573.89    ATL-D
# 4                   77400.00    ATL-F
# 6                  150000.00    ATL-D
# ...

# %%
df[~df["position"]== "M"]
#~ kullanimi ile de yapilabiliyor
#basina ~ diyerek haric anlami vermis oluyorsun

# %%
df[df["position"]!= "M"]
#bu cozumle ayni ~ ile cozumu

# %%
df["club"].value_counts().plot(kind="bar")
#pandasin kendi icinde de boyle grafik func'i var.
# Out:
# <AxesSubplot:>

# %%
df["club"].value_counts().plot(kind="pie")
#kind'in icine grafik turunu ekleyerek yapabiliyoruz
# Out:
# <AxesSubplot:ylabel='club'>

# %%
df["base_salary"].plot(kind="box")
# Out:
# <AxesSubplot:>
